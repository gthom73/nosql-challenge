# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
print("-----------------------------------------------------------------------------")
hygieneCount = establishments.count_documents(query)
print("Number of establishments with hygiene 20 is: ",hygieneCount)

# Display the first document in the results using pprint
print("-----------------------------------------------------------------------------")
print("First result:")
results = establishments.find(query)
pprint(results[0])

# Convert results to a Pandas DataFrame
print("-----------------------------------------------------------------------------")
hygieneCount_df = pd.DataFrame(results)

# Print the number of rows in the DataFrame
print("-----------------------------------------------------------------------------")
print("The number of rows in this DataFrame are: ", hygieneCount_df.shape[0])

# Display the first 10 rows
print("-----------------------------------------------------------------------------")
first10 = hygieneCount_df.head(10)
print(first10)
# Out:
# -----------------------------------------------------------------------------
# Number of establishments with hygiene 20 is:  41
# -----------------------------------------------------------------------------
# First result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': {'$toInt': '$RatingValue'},
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex': 'London'}}#, 'BusinessTypeID': {'$gte':4}}


result = list(establishments.find(query))

ratingValueCount = establishments.count_documents(query)
                                                  
# Use count_documents to display the number of documents in the result
print("-----------------------------------------------------------------------------")
print(f"Which establishments in London have a RatingValue greater than or equal to 4: {ratingValueCount}")

# Display the first document in the results using pprint
print("-----------------------------------------------------------------------------")
print("First establishment returned:")
result = establishments.find(query)


print('Number of establishments in London with a rating value of 4 or more: ', establishments.count_documents(query))

# Display the first document in the results using pprint
#pprint(result[0])
# Out:
# -----------------------------------------------------------------------------
# Which establishments in London have a RatingValue greater than or equal to 4: 37
# -----------------------------------------------------------------------------
# First establishment returned:
# Number of establishments in London with a rating value of 4 or more:  37

# %%
print("-----------------------------------------------------------------------------")
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(result)

print("-----------------------------------------------------------------------------")
# Display the number of rows in the DataFrame
print("The number of rows in this DataFrame are: ", london_df.shape[0])

print("-----------------------------------------------------------------------------")
# Display the first 10 rows of the DataFrame
first10 = london_df.head(10)
print(first10)
# Out:
# -----------------------------------------------------------------------------
# -----------------------------------------------------------------------------
# The number of rows in this DataFrame are:  37
# -----------------------------------------------------------------------------
#                         _id   FHRSID  ChangesByServerID  \
# 0  65cee2fd3241dab43e478575   621707                  0
# 1  65cee2fd3241dab43e47889f  1130836                  0
# 2  65cee2fd3241dab43e4793ed   293783                  0
# 3  65cee2fd3241dab43e4799f5  1523645                  0
# 4  65cee2fd3241dab43e47a1eb  1315095                  0
# 5  65cee2fd3241dab43e47a1f0   294474                  0
# 6  65cee2fd3241dab43e47a8f6   294900                  0
# 7  65cee2fe3241dab43e47ca01  1252616                  0
# 8  65cee2fe3241dab43e47ca06   293756                  0
# 9  65cee2fe3241dab43e47cdc6   878523                  0
#
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
#"longitude":"0.08384000",
#        "latitude":"51.49014200"
# Rating value must equal 5
# Sort by hygiene score

within = 0.01
latitude = 51.49014200
longitude = 0.0838400
query = {'LocalAuthorityName': {'$regex': 'London'}}
# query = {
#     'RatingValue': 5,
#     'geocode.latitude': {'$gte': latitude - within, '$lte': latitude + within},
#     'geocode.longitude': {'$gte': longitude - within, '$lte': longitude + within}
# }

sort = [('scores.Hygiene', 1)] 

# Print the results

result = list(establishments.find(query).sort(sort))

# Print the results
print('Number of establishments: ', len(result))
#display top 5 establishments
pprint(result)
# Out:
# Number of establishments:  37
# [{'AddressLine1': 'Tereza Joanne King George V Lock',
#   'AddressLine2': 'Woolwich Manor Way London',
#   'AddressLine3': 'Charlton',
#   'AddressLine4': '',
#   'BusinessName': 'Froottree',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4648.300000043045,
#   'FHRSID': 1252616,
#   'LocalAuthorityBusinessID': 'PI/000035653',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'E16 2NJ',
#   'RatingDate': '1901-01-01T00:00:00',
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65cee2fe3241dab43e47ca01'),
# ...

# %%
# Convert result to Pandas DataFrame
nearPenang_df = pd.DataFrame(result)
# Display the number of rows in the DataFrame
print('Number of rows in dataframe: ', len(nearpenang_df))
# Display the first 10 rows of the DataFrame
nearPenang_df
# Out:
# Number of rows in dataframe:  0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count':{'$sum': 1}}}
                                                                 
# 3. Sorts the matches from highest to lowest
sort_query = {'$sort': {'count': -1}}
                                                                 
result= list(establishments.aggregate([match_query, group_query, sort_query]))

# Print the number of documents in the result
print('The number of documents in the result is: ', len(result))

# Print the first 10 results
pprint(result[0:10])
# Out:
# The number of documents in the result is:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print('The number of rows in the DataFrame is: ', len(result_df))

# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# The number of rows in the DataFrame is:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
